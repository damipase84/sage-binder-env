# %%
var?
# Out:
# Signature:      var(*args, **kwds)
# Type:           cython_function_or_method
# String form:    <cyfunction var at 0x168149f20>
# File:           ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/calculus/var.pyx
# Docstring:
#    Create a symbolic variable with the name *s*.
#
#    INPUT:
#
#    * "args" -- a single string "var('x y')", a list of strings
#      "var(['x','y'])", or multiple strings "var('x', 'y')". A single
#      string can be either a single variable name, or a space or comma
#      separated list of variable names. In a list or tuple of strings,
#      each entry is one variable. If multiple arguments are specified,
#      each argument is taken to be one variable. Spaces before or after
#      variable names are ignored.
#
#    * "kwds" -- keyword arguments can be given to specify domain and
#      custom latex_name for variables; see EXAMPLES for usage
#
#    Note:
#
#      The new variable is both returned and automatically injected into
# ...

# %%
var('x')
# Out:
# x

# %%
x
# Out:
# x

# %%
type(x)
# Out:
# <class 'sage.symbolic.expression.Expression'>

# %%
factor(x^3+4*x^2+x-6)
# Out:
# (x + 3)*(x + 2)*(x - 1)

# %%
p(x)=x^3+4*x^2+x-6

# %%
factor(p)
# Out:
# x |--> (x + 3)*(x + 2)*(x - 1)

# %%
p(2)
# Out:
# 20

# %%
p(-2)
# Out:
# 0

# %%
type(p)
# Out:
# <class 'sage.symbolic.expression.Expression'>

# %%
q=x^3+4*x^2+x-6

# %%
type(q)
# Out:
# <class 'sage.symbolic.expression.Expression'>

# %%
expand(p^2)
# Out:
# x |--> x^6 + 8*x^5 + 18*x^4 - 4*x^3 - 47*x^2 - 12*x + 36

# %%
expand(q^2)
# Out:
# x^6 + 8*x^5 + 18*x^4 - 4*x^3 - 47*x^2 - 12*x + 36

# %%
q.is_polynomial
# Out:
# <bound method Expression.is_polynomial of x^3 + 4*x^2 + x - 6>

# %%
p.is_polynomial
# Out:
# <bound method Expression.is_polynomial of x |--> x^3 + 4*x^2 + x - 6>

# %%
p(1)
# Out:
# 0

# %%
q(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 q(Integer(1))
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/symbolic/expression.pyx:6200, in sage.symbolic.expression.Expression.__call__ (build/cythonized/sage/symbolic/expression.cpp:82931)()
#    6198         z^2 + x^y
#    6199     """
# -> 6200     return self._parent._call_element_(self, *args, **kwds)
#    6201
#    6202 def variables(self):
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/symbolic/ring.pyx:1038, in sage.symbolic.ring.SymbolicRing._call_element_ (build/cythonized/sage/symbolic/ring.c:14382)()
#    1036     d = args[0]
#    1037 else:
# -> 1038     raise TypeError("Substitution using function-call syntax "
#    1039                     "and unnamed arguments has been removed. You "
# ...

# %%
q(x=1)
# Out:
# 0

# %%
q(x=1)
# Out:
# 0

# %%
t(x)=x^4-5*x^2+5

# %%
factor(t)
# Out:
# x |--> x^4 - 5*x^2 + 5

# %%
t.roots(ring=RR)
# Out:
# [(-1.90211303259031, 1),
#  (-1.17557050458495, 1),
#  (1.17557050458495, 1),
#  (1.90211303259031, 1)]

# %%
roots(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 roots(t)
#
# NameError: name 'roots' is not defined

# %%
a=solve(t)
a
# Out:
# [x == -sqrt(1/2*sqrt(5) + 5/2),
#  x == sqrt(1/2*sqrt(5) + 5/2),
#  x == -sqrt(-1/2*sqrt(5) + 5/2),
#  x == sqrt(-1/2*sqrt(5) + 5/2)]

# %%
a
# Out:
# [x == -sqrt(1/2*sqrt(5) + 5/2),
#  x == sqrt(1/2*sqrt(5) + 5/2),
#  x == -sqrt(-1/2*sqrt(5) + 5/2),
#  x == sqrt(-1/2*sqrt(5) + 5/2)]

# %%
a(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 a(Integer(1))
#
# TypeError: 'Sequence_generic' object is not callable

# %%
a[1]
# Out:
# x == sqrt(1/2*sqrt(5) + 5/2)

# %%
t(a[1])
# Out:
# (x == sqrt(1/2*sqrt(5) + 5/2))^4 - 5*(x == sqrt(1/2*sqrt(5) + 5/2))^2 + 5

# %%
t(0)
# Out:
# 5

# %%
t(sqrt(1/2*sqrt(5) + 5/2))
# Out:
# 1/4*(sqrt(5) + 5)^2 - 5/2*sqrt(5) - 15/2

# %%
solve?
# Out:
# Signature:
# solve(
#     f,
#     explicit_solutions,
#     multiplicities,
#     to_poly_solve,
#     solution_dict,
#     algorithm,
#     domain,
#     *args,
# )
# Docstring:
#    Algebraically solve an equation or system of equations (over the
#    complex numbers) for given variables. Inequalities and systems of
#    inequalities are also supported.
#
#    INPUT:
#
#    * "f" -- equation or system of equations (given by a list or tuple)
#
#    * "*args" -- variables to solve for
#
#    * "solution_dict" -- boolean (default: "False"); if "True" or
#      nonzero, return a list of dictionaries containing the solutions.
#      If there are no solutions, return an empty list (rather than a
#      list containing an empty dictionary). Likewise, if there's only a
#      single solution, return a list containing one dictionary with
#      that solution.
#
#    There are a few optional keywords if you are trying to solve a
#    single equation.  They may only be used in that context.
# ...

# %%
solve(t==0)
# Out:
# [x == -sqrt(1/2*sqrt(5) + 5/2),
#  x == sqrt(1/2*sqrt(5) + 5/2),
#  x == -sqrt(-1/2*sqrt(5) + 5/2),
#  x == sqrt(-1/2*sqrt(5) + 5/2)]

# %%
t(0)
# Out:
# 5

# %%
t(-sqrt(1/2*sqrt(5) + 5/2))
# Out:
# 1/4*(sqrt(5) + 5)^2 - 5/2*sqrt(5) - 15/2

# %%
t
# Out:
# x |--> x^4 - 5*x^2 + 5

# %%
simplify(1/4*(sqrt(5) + 5)^2 - 5/2*sqrt(5) - 15/2)
# Out:
# 1/4*(sqrt(5) + 5)^2 - 5/2*sqrt(5) - 15/2

# %%
p(x)=x^2+1

# %%
factor(p,CC)
# Out:
# x |--> x^2 + 1

# %%
solve(p)
# Out:
# [x == -I, x == I]

# %%
solve(p,ring=RR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 solve(p,ring=RR)
#
# TypeError: solve() got an unexpected keyword argument 'ring'

# %%
help solve
# Out:
#   Cell In[80], line 1
#     help solve
#          ^
# SyntaxError: invalid syntax

# %%
solve?
# Out:
# Signature:
# solve(
#     f,
#     explicit_solutions,
#     multiplicities,
#     to_poly_solve,
#     solution_dict,
#     algorithm,
#     domain,
#     *args,
# )
# Docstring:
#    Algebraically solve an equation or system of equations (over the
#    complex numbers) for given variables. Inequalities and systems of
#    inequalities are also supported.
#
#    INPUT:
#
#    * "f" -- equation or system of equations (given by a list or tuple)
#
#    * "*args" -- variables to solve for
#
#    * "solution_dict" -- boolean (default: "False"); if "True" or
#      nonzero, return a list of dictionaries containing the solutions.
#      If there are no solutions, return an empty list (rather than a
#      list containing an empty dictionary). Likewise, if there's only a
#      single solution, return a list containing one dictionary with
#      that solution.
#
#    There are a few optional keywords if you are trying to solve a
#    single equation.  They may only be used in that context.
# ...

# %%
solve(p,domain=real)
# Out:
# [x == -I, x == I]

# %%
p.roots()
# Out:
# [(-I, 1), (I, 1)]

# %%
pp=p^2

# %%
pp.roots()
# Out:
# [(-I, 2), (I, 2)]

# %%
p.roots(ring=)
# Out:
# [(-1.00000000000000*I, 1), (1.00000000000000*I, 1)]

# %%
var('a,b,c')
# Out:
# (a, b, c)

# %%
p(x)=a*x^2+b*x+c

# %%
p(0)
# Out:
# c

# %%
p(1)
# Out:
# a + b + c

# %%
p.roots()
# Out:
# [(-(b*x + c)/x^2, 1)]

# %%
roots?
# Out:
# Object `roots` not found.

# %%
p.roots?
# Out:
# Signature:
# p.roots(
#     self,
#     x=None,
#     explicit_solutions=True,
#     multiplicities=True,
#     ring=None,
# )
# Docstring:
#    Return roots of "self" that can be found exactly, possibly with
#    multiplicities.  Not all roots are guaranteed to be found.
#
# ...
#
#      This is *not* a numerical solver - use "find_root()" to solve for
#      "self == 0" numerically on an interval.
#
#    INPUT:
#
#    * "x" -- variable to view the function in terms of (use default
#      variable if not given)
#
#    * "explicit_solutions" -- boolean (default: "True"); require that
#      roots be explicit rather than implicit
#
#    * "multiplicities" -- boolean (default: "True"); when "True",
#      return multiplicities
#
#    * "ring" -- a ring (default: "None"); if not "None", convert "self"
#      to a polynomial over "ring" and find roots over "ring"
#
#    OUTPUT:
#
#    A list of pairs "(root, multiplicity)" or list of roots.
#
# ...

# %%
zerosp=p.roots(x,multiplicities=False)
zerosp[1]
# Out:
# -1/2*(b - sqrt(b^2 - 4*a*c))/a

# %%
type(zerosp)
# Out:
# <class 'list'>

# %%
solve(p(x)>=0,x)
# Out:
# [[a*x^2 + b*x + c == 0], [a*x^2 + b*x + c > 0]]

# %%
p.roots?
# Out:
# Signature:
# p.roots(
#     self,
#     x=None,
#     explicit_solutions=True,
#     multiplicities=True,
#     ring=None,
# )
# Docstring:
#    Return roots of "self" that can be found exactly, possibly with
#    multiplicities.  Not all roots are guaranteed to be found.
#
# ...
#
#      This is *not* a numerical solver - use "find_root()" to solve for
#      "self == 0" numerically on an interval.
#
#    INPUT:
#
#    * "x" -- variable to view the function in terms of (use default
#      variable if not given)
#
#    * "explicit_solutions" -- boolean (default: "True"); require that
#      roots be explicit rather than implicit
#
#    * "multiplicities" -- boolean (default: "True"); when "True",
#      return multiplicities
#
#    * "ring" -- a ring (default: "None"); if not "None", convert "self"
#      to a polynomial over "ring" and find roots over "ring"
#
#    OUTPUT:
#
#    A list of pairs "(root, multiplicity)" or list of roots.
#
# ...

# %%
p
# Out:
# x |--> a*x^2 + b*x + c

# %%
p(a=1)
# Out:
# b*x + x^2 + c

# %%
p(10,a=1,b=1,c=1)
# Out:
# 111

# %%
zeros(a,b,c)=p.roots(x,multiplicities=False,ring=RR)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 __tmp__=var("a,b,c"); zeros = symbolic_expression(p.roots(x,multiplicities=False,ring=RR)).function(a,b,c)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/symbolic/expression.pyx:12279, in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:118019)()
#   12277 if ring is not None:
#   12278     p = self.polynomial(ring)
# > 12279     return p.roots(ring=ring, multiplicities=multiplicities)
#   12280
#   12281 S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:13068)()
# ...

# %%
zeros(1,2,2)
# Out:
# (-I - 1, I - 1)

# %%
p.roots()
# Out:
# [(-(b*x + c)/x^2, 1)]

# %%
q(x)=x^2+2*x+2

# %%
q.roots(multiplicities=False,ring=RR)
# Out:
# []

# %%
solve(x*(1-x^2)>=0)
# Out:
# [[x <= -1], [x >= 0, x <= 1]]

# %%
solve(x^2+1>=0)
# Out:
# [x < +Infinity]

# %%
solve(x^2<=0)
# Out:
# [[x == 0]]

# %%
espr=2*x^2-3*x+1<=-2*x^2+4*x

# %%
espr
# Out:
# 2*x^2 - 3*x + 1 <= -2*x^2 + 4*x

# %%
espr=espr+2*x^2-4*x
espr
# Out:
# 4*x^2 - 7*x + 1 <= 0

# %%
espr*-1
# Out:
# -4*x^2 + 7*x - 1 <= 0

# %%
solve(abs(5*x-1)>=x)
# Out:
# [[x == (1/4)],
#  [x == (1/6)],
#  [x == 0],
#  [0 < x, x < (1/6)],
#  [(1/4) < x],
#  [x < 0]]

# %%
solve(x^2+abs(x+1)-4==0)
# Out:
# [x == -sqrt(-abs(x + 1) + 4), x == sqrt(-abs(x + 1) + 4)]

# %%
solve(abs(5*x-1)>=x)
# Out:
# [[x == (1/4)],
#  [x == (1/6)],
#  [x == 0],
#  [0 < x, x < (1/6)],
#  [(1/4) < x],
#  [x < 0]]

# %%
esp=2^2*(2^2)^(5)

# %%
esp
# Out:
# 4096

# %%
esp.factor()
# Out:
# 2^12

# %%
a=solve(x^2+x+1-4)

# %%
a.n
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 a.n
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/sequence.py:939, in Sequence_generic.__getattr__(self, name)
#     936     self.__hash = self._Sequence__hash
#     937     return self.__hash
# --> 939 raise AttributeError("'Sequence_generic' object has no attribute '%s'" % name)
#
# AttributeError: 'Sequence_generic' object has no attribute 'n'

# %%
a
# Out:
# [x == -1/2*sqrt(13) - 1/2, x == 1/2*sqrt(13) - 1/2]

# %%
a.n()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[198], line 1
# ----> 1 a.n()
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/sequence.py:939, in Sequence_generic.__getattr__(self, name)
#     936     self.__hash = self._Sequence__hash
#     937     return self.__hash
# --> 939 raise AttributeError("'Sequence_generic' object has no attribute '%s'" % name)
#
# AttributeError: 'Sequence_generic' object has no attribute 'n'

# %%
a[1].n
# Out:
# <bound method Element.n of x == 1/2*sqrt(13) - 1/2>

# %%
a.dumps()
# Out:
# b'x\x9c\xb5\x92\xcfJ\x031\x10\xc6\'\xd9\xb5\xd5\xad\x7fZA\x0f>\x81"V\xd4\'("B=\x08\xad\x87^\xa4d\xd3\xb1]\xd9&\x9ddW+"(\x1ej\xf1\xe8\xd1\x93\xaf\xd0W\xf0y\xf6\x1d\xcc\xda\xa2 \xde\xc4\xd3|\x132\x93\xefG\xbe{.\xad\xe8b\xd5&&\x95Ij\x9cBJQI\x0c\x9a3\xd1\xee\xa2B\x13\xc9\x80`\xf3\x9c\xd8\xe6l\xe0\xa6\x1f\xea8\x92U\x1c\x0e\x0cZ\x1bi\x15\x1c}K\xe2[\x0f\xe4\x9d\xc09\xf9-\x06\x00C\x9a\x13\xadw\'\x8ek\x8dCo]\xc6\xc2Z0\x18\x8b\xc4\xdd\x161L\xd7\x81\x12}\x84!\xc4=\x10\x9d\x0e\x0c\xf45\x1a8\x83&\xec\x1d\x80J\xfb\xb9\x0b\x08\x85\x8d,\xec\xed\xee\x83{Y+T\x89\xdbc\x13\xd8\xc9\x8f\xa4\xc6\x8b\x0b\xd0WhD\x1c\xb7\xa7\x9d\xe9\x81\x1e@n\xba\x8dC`k\x85"\xe7|\xc3\xf7j\xac\x1e\xf0\x92W\xf3\xebK\xae\xf0\xa2d\x96\xe7]\x99\x97|^\xb8\xf5\xb2\xc93\xf3\xb3\xc9\x0b\xf3}\xce\xb6!\x9b\xbc\xb2\xb9l\xf2\xc6\x80\n#*\x86\xbd\x9cp>\'\\\xe8\xfd7\xdb\x14\xe4\x93\xf0ol\x95/\xb6G\xc6\x7fe\x0bFT\n\xf1g(R\x15\xb90\xb4\r\xe6\x1f\xecl}\xa2\x05\xa92\xd8I]Thq: E\x82]m"\xb4U\x1d^\xa2Llp:\xab\xb4\xb4uG\xcb#ZiPy<~J\xa8\xd2\xa0\xd5\x
# ...

# %%
a.pop?
# Out:
# Signature:      a.pop(self, index=-1)
# Docstring:
#    Remove and return item at index "index" (default: last).
#
#    EXAMPLES:
#
#       sage: B = Sequence([1,2,3])
#       sage: B.pop(1)
#       2
#       sage: B
#       [1, 3]
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:           ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/sequence.py
# Type:           method

# %%
esp(x)=x^2+x+1==4

# %%
esp
# Out:
# x |--> x^2 + abs(x + 1) == 4

# %%
solve_ineq([esp])
# Out:
# [[x^2 + x - 3 == 0]]

# %%
simplify(esp)
# Out:
# x |--> x^2 + abs(x + 1) == 4

# %%
find_root(x^2 + abs(x + 1) == 4,-1,10)
# Out:
# 1.3027756377319948

# %%
simplify(solve(abs(5*x-1)>x))
# Out:
# [[x == 0], [0 < x, x < (1/6)], [(1/4) < x], [x < 0]]

# %%
aa=solve(abs(5*x-1)>x)

# %%
aa.sort()

# %%
aa
# Out:
# [[x == 0], [0 < x, x < (1/6)], [(1/4) < x], [x < 0]]

# %%
aa.simplify
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 aa.simplify
#
# AttributeError: 'list' object has no attribute 'simplify'

# %%
aa.extend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[239], line 1
# ----> 1 aa.extend()
#
# TypeError: list.extend() takes exactly one argument (0 given)

# %%
aa.append
# Out:
# <built-in method append of list object at 0x356c52d40>

# %%
solve_ineq(abs(5*x-1)>=x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/interfaces/interface.py:753, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     752 try:
# --> 753     self._name = parent._create(value, name=name)
#     754 except (TypeError, RuntimeError, ValueError) as x:
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/interfaces/maxima_lib.py:624, in MaximaLib._create(self, value, name)
#     623     else:
# --> 624         self.set(name, value)
#     625 except RuntimeError as error:
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/interfaces/maxima_lib.py:534, in MaximaLib.set(self, var, value)
#     533 cmd = '%s : %s$' % (var, value.rstrip(';'))
# --> 534 self.eval(cmd)
#
# ...

# %%
solve_ineq?
# Out:
# Signature:      solve_ineq(ineq, vars=None)
# Docstring:
#    Solve inequalities and systems of inequalities using Maxima.
#    Switches between rational inequalities
#    (sage.symbolic.relation.solve_ineq_rational) and Fourier
#    elimination (sage.symbolic.relation.solve_ineq_fouried). See the
#    documentation of these functions for more details.
#
#    INPUT:
#
#    * "ineq" -- one inequality or a list of inequalities
#
#      Case1: If "ineq" is one equality, then it should be rational
#      expression in one variable. This input is passed to
#      sage.symbolic.relation.solve_ineq_univar function.
#
#      Case2: If "ineq" is a list involving one or more inequalities,
#      than the input is passed to
#      sage.symbolic.relation.solve_ineq_fourier function. This function
#      can be used for system of linear inequalities and for some types
#      of nonlinear inequalities. See http://maxima.cvs.sourceforge.net
# ...

# %%
solve_ineq(x^2>=0)
# Out:
# [x < +Infinity]

# %%
esp
# Out:
# x |--> x^2 + x + 1 == 4

# %%
esp=x^2+abs(x+1)==4
assume(x>-1)
esp.simplify()
# Out:
# x^2 + x + 1 == 4

# %%
f = abs(x-3) - abs(x+5)
assume(x < 4)
f.simplify() # Simplifies based on the assumption
# Out:
#   Cell In[259], line 1
#     clear x
#           ^
# SyntaxError: invalid syntax

# %%
esp.simplify()
# Out:
# x^2 + x + 1 == 4

# %%
sqrt(3^2+1.5^2)
# Out:
# 3.35410196624968

# %%
a=var('a')

# %%
b=var('b')

# %%
# %display latex
simplify((a^(-5)/(a^(-2)*b^(-1)))^6)
# Out:
# b^6/a^18
