# %% [markdown]
# # Disequazioni polinomiali e razionali fratte

# %% [markdown]
# ## Disequazioni
#
# ### Esempio 1 - Disequazione polinomiale
#
# Risolvere
# $$t^6+8t^5\geq -12t^4$$
#
# Soluzione:
# \begin{align*}
# t^6+8t^5+12t^4&\geq 0\\
# t^4(t^2+8t+12) &\geq 0\\
# t^4(t+6)(t+2)  &\geq 0
# \end{align*}
# $t^4$ è un fattore non negativo, per cui il segno è dato da $(t+6)(t+2)$:
# $$t\leq -6 \ \lor t\geq -2$$

# %% [markdown]
# Vediamo come ottenere queste soluzioni in Sage.

# %%
# %display latex
t=var('t')
dis=t^6+8*t^5>=-12*t^4
dis
# Out:
# t^6 + 8*t^5 >= -12*t^4

# %%
solve(dis)
# Out:
# [[t <= -6], [t >= -2]]

# %% [markdown]
# Questo equivale a $t\leq -6 \lor t\geq -2$, infatti:

# %%
load('utils_DP.sage') # carica le funzioni nel file utils_DP
ss=solve(dis)
interval_sol(ss)
# Out:
# (-oo, -6] ∪ [-2, +oo)

# %% [markdown]
# Vediamo ora come Sage ci può aiutare a controllare i nostri passaggi

# %%
show(dis)
# Out:
# t^6 + 8*t^5 >= -12*t^4

# %%
dis1=dis-dis.right()
dis1
# Out:
# t^6 + 8*t^5 + 12*t^4 >= 0

# %%
dis1.left().factor()
# Out:
# (t + 6)*(t + 2)*t^4

# %% [markdown]
# A questo punto ci rimane da fare lo studio del segno.

# %%
plot_sign([x+6,x+2],[]) # plot_sign([fact1,fact2],[CE])
# Out:
# Graphics object consisting of 21 graphics primitives

# %% [markdown]
# ### Esempio 2 - Disequazione razionale fratta

# %%
dis=(3*x+1)/(x+4)>=1
dis
# Out:
# (3*x + 1)/(x + 4) >= 1

# %%
sol=solve(dis)
sol
# Out:
# [[x < -4], [x >= (3/2)]]

# %%
interval_sol(sol)
# Out:
# (-oo, -4) ∪ [3/2, +oo)

# %% [markdown]
# Vediamo di verificare i passaggi con sage:

# %%
interval_sol(solve(x+4!=0))  # Condizioni di esistenza
# Out:
# (-oo, -4) ∪ (-4, +oo)

# %%
show(dis)
dis1=dis-1
show(dis1)
# Out:
# (3*x + 1)/(x + 4) >= 1
# (3*x + 1)/(x + 4) - 1 >= 0

# %%
dis1=dis1.factor()
show(dis1)
# Out:
# (2*x - 3)/(x + 4) >= 0

# %% [markdown]
# A questo punto bisogna fare lo studio del segno di numerotore e denominatore

# %%
def plot_sign_fracs(num,den,condizioni):
    nf=2 # numero fattori
    factor_list=[num, den]
    fun=num/den
    cc=solve(condizioni)
    cc1=solve(den!=0)
    cc_Set=interval_sol(cc)
    cc_Set=cc_Set.intersection(interval_sol(cc1)) # condizioni esistenza
    ss=solve(fun>=0)
    ss_Set=interval_sol(ss)
    sol_Set=ss_Set.intersection(cc_Set)

    bound=sol_Set.boundary() # boundary values
    nb=bound.n_components()
    if nb>1:
        bound_min=bound[0].lower()
        bound_max=bound[-1].lower()
        leng=bound_max-bound_min
        val_xmin=bound_min-0.4*leng
        val_xmax=bound_max+0.4*leng
    else:
        bound_mean=bound[0].lower()
        val_xmin=bound_mean-5
        val_xmax=bound_mean+5

    ll=line([[val_xmin,0.1],[val_xmax,0.1]],color='black',thickness=0.5)
    ll=ll+text('$x$',[val_xmax,0.3])
    for i in range(nb):
        bound_val=bound[i].lower()
        ll=ll+line([[bound_val,0.1],[bound_val,-nf-1.1]],color='black',thickness=0.5)
        ll=ll+text(bound_val,[bound_val,0.3])
        
    for i in range(nf):

        fact=factor_list[i]
        ss=solve(fact>=0)
        fact_Set=interval_sol(ss)
        ll=ll+line_sign(fact_Set,sol_Set,cc_Set,-i-1,fact)
    ll=ll+line_sign(sol_Set,sol_Set,cc_Set,-nf-1,fun)
    ll.axes_color('white')
    ll.axes_label_color('white')
    ll.tick_label_color('white')
    show(ll,axes_labels=['$x$',' '],ymin=-nf-2,ymax=0.2,ticks=[None,None],figsize=[5,3])
###########################

def line_sign(fact_Set,sol_Set,cc_Set,yval,fun):
    bound=sol_Set.boundary() # boundary values
    bound_fact=fact_Set.boundary()
    nb=bound.n_components()
    if nb>1:
        bound_min=bound[0].lower()
        bound_max=bound[-1].lower()
        leng=bound_max-bound_min
        val_xmin=bound_min-0.4*leng
        val_xmax=bound_max+0.4*leng
    else:
        bound_mean=bound[0].lower()
        leng=10
        val_xmin=bound_mean-5
        val_xmax=bound_mean+5
    xvali=bound[0].lower()
    ll=line([[val_xmin,yval],[val_xmax,yval]],color='blue',linestyle='--',thickness=1)
    if cc_Set.inf()==xvali:
        ll=ll+line([[val_xmin,yval],[xvali,yval]],color='red')
    elif fact_Set.inf()==-oo:
        ll=ll+line([[val_xmin,yval],[xvali,yval]],color='blue')
    for i in range(nb):
        xvali=bound[i].lower()
        if xvali not in cc_Set:
            ll=ll+point([[xvali,yval]],size=50,color='red')
        elif xvali in bound_fact:
            ll=ll+point([[xvali,yval]],size=50,color='blue')
        if i != nb-1: 
            xvalip1=bound[i+1].lower()
            xvalm=(xvalip1+xvali)/2
            if xvalm not in cc_Set:
                ll=ll+line([[xvali,yval],[xvalip1,yval]],color='red')
            elif xvalm in fact_Set:
                ll=ll+line([[xvali,yval],[xvalip1,yval]],color='blue')
        elif i==nb-1: 
            if cc_Set.sup()==xvali:
                ll=ll+line([[bound[-1].lower(),yval],[val_xmax,yval]],color='red')
            elif fact_Set.sup()==+oo:
                ll=ll+line([[bound[-1].lower(),yval],[val_xmax,yval]],color='blue')
    ll=ll+text(fun,[val_xmin-0.2*leng,yval+0.2])
    return ll

# %%
plot_sign_fract(2*x-3,x+4,[x+4!=0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[304], line 1
# ----> 1 plot_sign_fract(Integer(2)*x-Integer(3),x+Integer(4),[x+Integer(4)!=Integer(0)])
#
# NameError: name 'plot_sign_fract' is not defined

# %% [markdown]
# ## Esempi visti nei video

# %% [markdown]
# ### Esempio 1

# %%
dis=x^3+4*x^2-12*x<= 0
dis
# Out:
# x^3 + 4*x^2 - 12*x <= 0

# %%
ss=solve(dis)
interval_sol(ss)
# Out:
# (-oo, -6] ∪ [0, 2]

# %% [markdown]
# Questo equivale a $x<-6 \lor 0<x<2$. Vediamo con `interval_sol`:

# %%
interval_sol(ss)
# Out:
# (-oo, -6] ∪ [0, 2]

# %% [markdown]
# Sage ci può aiturare a verificare i nostri passaggi ad esempio fattorizzando il membro di sinistra:

# %%
dis1=dis.left().factor()
dis1
# Out:
# (x + 6)*(x - 2)*x

# %%
plot_sign([x+6,x-2,x],[])
# Out:
# Graphics object consisting of 30 graphics primitives

# %% [markdown]
# ### Esempio 2

# %%
dis=2*(-x^2-1)*(x-1)^2*(x+sqrt(2))<= 0
dis
# Out:
# -2*(x^2 + 1)*(x + sqrt(2))*(x - 1)^2 <= 0

# %%
ss=solve(dis)
interval_sol(ss)
# Out:
# [-sqrt(2), +oo)

# %% [markdown]
# Questo equivale a $-\sqrt{2}\leq x$

# %% [markdown]
# Potete usare Sage per verificare il segno dei singoli fattori
