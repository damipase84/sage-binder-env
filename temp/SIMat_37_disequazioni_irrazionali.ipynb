# %% [markdown]
# # Disequazioni irrazionali

# %% [markdown]
# Per prima cosa vediamo come fare le radici $n$-esime in Sage.
# Per radicandi positivi possiamo usare le potenze:

# %%
8^(1/3)
# Out:
# 2

# %% [markdown]
# Se vogliamo applicare le radici con indici dispari a radicandi negativi è meglio usare il metodo `.nth_root`. Vediamo un esempio:

# %%
a=(-8)^(1/3)   # base negativa
show(a.n())
# Out:
# 1.00000000000000 + 1.73205080756888*I

# %%
(-8).nth_root(3)
# Out:
# -2

# %%
8.nth_root(3)
# Out:
# 2

# %% [markdown]
# Il seguente codice crea una funzione per avere funzioni $x^{p/q}$ ben definite anche per $x<0$ quando $q$ è dispari:

# %%
x=var('x')
def power_pq(x,p,q):
    if is_odd(q):
        val=((sign(x))^p)*abs(x)^(p/q)
    else:
        val=x^(p/q)   
    return val

# %%
f(x)=power_pq(x,1,3) # esempio di radice cubica
plot(f,[-10,10])
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Risoluzione di disequazioni irrazionali

# %% [markdown]
# ## Esempio
#
# Risolvere $$1\leq x-2\sqrt{2x-3}$$

# %%
# %display latex
dis=1<=x-2*sqrt(2*x-3)
dis
# Out:
# 1 <= x - 2*sqrt(2*x - 3)

# %% [markdown]
# A volte è utile aggiungere l'opzione `algorithm='sympy'` al comando `solve`, ma in questo caso comunque non riesce a trovare le soluzioni esatte:

# %%
solve(dis,algorithm='sympy')
# Out:
# [[x <= -2*sqrt(3) + 5], [x >= 2*sqrt(3) + 5]]

# %% [markdown]
# Vediamo i passaggi per risolvere questa disequazione irrazionale:

# %%
dis1=(dis-x)/2
dis1
# Out:
# -1/2*x + 1/2 <= -sqrt(2*x - 3)

# %% [markdown]
# Invece di moltiplicare per $-1$, invertiamo i membri:

# %%
dis2=dis1-dis1.right()-dis1.left()
dis2
# Out:
# sqrt(2*x - 3) <= 1/2*x - 1/2

# %%
f(x)=dis2.left()^2
g(x)=dis2.right()

# %% [markdown]
#  $$\text{Caso 1):}\  \begin{cases}
# g(x)\geq 0\\
# f(x)\geq 0\\
# f(x)\leq g^2(x)
# \end{cases}\quad ,\quad  \text{Caso 2):}\ \begin{cases}
# g(x)< 0\\
# f(x)\geq 0\\
# \sqrt{f(x)}\leq g(x)
# \end{cases}
# \implies \nexists $$

# %%
solve(g(x)>=0)
# Out:
# [[x >= 1]]

# %%
solve(f(x)>=0)
# Out:
# [[x >= (3/2)]]

# %%
dis3=f(x)<=g(x)^2
dis3=dis3.expand()
dis3=dis3-dis3.right()
dis3()
# Out:
# -1/4*x^2 + 5/2*x - 13/4 <= 0

# %%
forget()
solve(f(x)<=g(x)^2,algorithm='sympy')
# Out:
# [[x <= -2*sqrt(3) + 5], [x >= 2*sqrt(3) + 5]]

# %%
forget()

# %%
solve([x>=1,x>=3/2,dis3],algorithm='sympy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 solve([x>=Integer(1),x>=Integer(3)/Integer(2),dis3],algorithm='sympy')
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/symbolic/relation.py:1236, in solve(f, explicit_solutions, multiplicities, to_poly_solve, solution_dict, algorithm, domain, *args)
#    1230             return [[v._sage_() == ex._sage_()
#    1231                      for v, ex in d.items()] for d in ret]
#    1232     else:
#    1233         # it is not clear how this branch could be reached
#    1234         # because dict=True is passed above, however
#    1235         # it is kept just in case
# -> 1236         return sympy_set_to_list(ret, sympy_vars)
#    1238 if algorithm == 'giac':
#    1239     return _giac_solver(f, x, solution_dict)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/interfaces/sympy.py:1372, in sympy_set_to_list(set, vars)
#    1369     return [[item for rel in set._args[0]
#    1370             for item in sympy_set_to_list(rel, vars)]]
#    1371 elif isinstance(set, Or):
# -> 1372     return [sympy_set_to_list(iv, vars) for iv in set._args[0]]
#    1373 elif isinstance(set, Relational):
#    1374     return [set._sage_()]
#
# TypeError: 'And' object is not iterable

# %% [markdown]
# ## Esempi visti a lezione

# %% [markdown]
# ### Esempio - indice dispari

# %% [markdown]
# Riproponiamo l'esempio visto nella lezione:
#
# $$\sqrt[3]{x^3-16}\geq -x$$

# %%
# %display latex
dis1=power_pq(x^3-16,1,3)>=-x

# %%
dis1

# %%
solve(dis1,algorithm='sympy')

# %%
dis=((x^3-16)^(1/3)>=-x)

# %%
solve(dis,to_poly_solve=true)

# %% [markdown]
# In questo caso `solve` non riesce a trovare la soluzione.
# Facciamo i passaggi per la risoluzine:

# %%
dis2=dis^3
dis2

# %%
solve(dis2)

# %% [markdown]
# In questo caso è facile fare tutti i passaggi per arrivare alla fine

# %%
dis3=dis2+x^3+16
dis4=dis3/2
show(dis4)

# %%
dis5=dis4^(1/3)
show(dis5)
show(dis5.canonicalize_radical())

# %% [markdown]
# ## Esempio - indice pari

# %%
dis=sqrt(x^2-9)>= 3-1/5*x
dis

# %%
solve(dis,algorithm='sympy')

# %% [markdown]
# Facciamo i passaggi.
# Caso 1: rhs >=0
# Risolviamo:
#
# $$\text{Caso 1}\  \begin{cases}
# -\frac15 x+3\geq 0 \\
# x^2-9\geq 0\\
# x^2-9\geq (-\frac 15 x+3)^2
# \end{cases}\qquad,\qquad \text{Caso 2}\ \begin{cases}
# -\frac15 x+3< 0 \\
# x^2-9\geq 0\\
# \end{cases} $$

# %%
g(x)=dis.right()
g(x)

# %%
f(x)=x^2-9

# %%
dis^2

# %%
S1=solve([g(x)>=0,f(x)>=0,dis^2])
S1

# %%
S2=solve([g(x)<0,f(x)>=0])
S1+S2

# %% [markdown]
# ## Grafico di funzioni potenza
#
# Vogliamo capire come cambia il grafico di funzioni
# $$y=x^{\alpha}$$
# con $\alpha \in \mathbb{R}$ e $x>0$.

# %%
@interact
def _(a=slider(-3,3,step_size=0.02)):                    # usiamo uno slider 
    show(plot(x^a,(x,0, 3),ymin=-2,ymax=10, color='red'))
