# %%
x m n=SR.var(x m n)
# Out:
#   Cell In[9], line 1
#     x m n=SR.var(x m n)
#       ^
# SyntaxError: invalid syntax

# %%
simplify((x^2)^(3/2))
# Out:
# (x^2)^(3/2)

# %%
a=var('a')

# %%
b,c=var('b','c')

# %%
nn=var('nn')

# %%
nn=100*a+10*b+c

# %%
assume(a,'integer')

# %%
assume(b,c,'integer')

# %%
assume(a,<10)
# Out:
#   Cell In[20], line 1
#     assume(a,<Integer(10))
#              ^
# SyntaxError: invalid syntax

# %%
cont=0
for i in range(1,9)
    print(i)
# Out:
#   Cell In[21], line 2
#     for i in [Integer(1),Integer(9)]
#                                     ^
# SyntaxError: expected ':'

# %%
range[1,9]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 range[Integer(1),Integer(9)]
#
# TypeError: type 'range' is not subscriptable

# %%
range(1,9)
# Out:
# range(1, 9)

# %%
range(9)
# Out:
# range(0, 9)

# %%
cont=0
for i in range(1,10):
    for j in range(10):
        for k in range(10):
            n=100*i+10*j+k
            d=1000
            if j==0:
                if k==0:
                    d=i
                else:
                    d=10*i+k
            elif k==0:
                d=10*i+j
            if n%d==0:
                cont=cont+1
                print(100*i+10*j+k)
print(cont)
# Out:
# 100
# 105
# 108
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 330
# 340
# 350
# 360
# 370
# 380
# 390
# 400
# 405
# 410
# 420
# 430
# 440
# 450
# 460
# 470
# 480
# 490
# 500
# 510
# 520
# 530
# 540
# 550
# 560
# 570
# 580
# 590
# 600
# 610
# 620
# 630
# 640
# 650
# 660
# 670
# 680
# 690
# 700
# 710
# 720
# 730
# 740
# 750
# 760
# 770
# 780
# 790
# 800
# 810
# 820
# 830
# 840
# 850
# 860
# 870
# 880
# 890
# 900
# 910
# 920
# 930
# 940
# 950
# 960
# 970
# 980
# 990
# 93

# %%
range(9)
# Out:
# range(0, 9)
